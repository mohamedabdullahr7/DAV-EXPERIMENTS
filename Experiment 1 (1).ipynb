# %%
import sys

print("Python Version:", sys.version)
# Out:
# Python Version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
# !pip install numpy scipy jupyter statsmodels pandas matplotlib seaborn plotly bokeh
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 73.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 913.3/913.3 kB 40.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 89.5 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import scipy
import pandas as pd
import matplotlib
import seaborn as sns
import statsmodels.api as sm
import plotly
import bokeh

# %%
import numpy as np
import pandas as pd
import matplotlib
import seaborn as sns
import statsmodels
import scipy
import plotly
import bokeh

print("NumPy Version:", np.__version__)
print("Pandas Version:", pd.__version__)
print("Matplotlib Version:", matplotlib.__version__)
print("Seaborn Version:", sns.__version__)
print("Statsmodels Version:", statsmodels.__version__)
print("SciPy Version:", scipy.__version__)
print("Plotly Version:", plotly.__version__)
print("Bokeh Version:", bokeh.__version__)
# Out:
# NumPy Version: 2.0.2
# Pandas Version: 2.2.2
# Matplotlib Version: 3.10.0
# Seaborn Version: 0.13.2
# Statsmodels Version: 0.14.6
# SciPy Version: 1.16.3
# Plotly Version: 5.24.1
# Bokeh Version: 3.8.2

# %%
# !jupyter --version
# Out:
# Selected Jupyter core packages...
# IPython          : 7.34.0
# ipykernel        : 6.17.1
# ipywidgets       : 7.7.1
# jupyter_client   : 7.4.9
# jupyter_core     : 5.9.1
# jupyter_server   : 2.20.0
# jupyterlab       : 4.6.2
# nbclient         : 0.10.4
# nbconvert        : 7.17.1
# nbformat         : 5.10.4
# notebook         : 6.5.7
# qtconsole        : not installed
# traitlets        : 5.7.1

# %%
import numpy as np

arr = np.array([10, 20, 30, 40, 50])

print("Array:", arr)
print("Mean:", np.mean(arr))
print("Maximum:", np.max(arr))
print("Minimum:", np.min(arr))
print("Sum:", np.sum(arr))
# Out:
# Array: [10 20 30 40 50]
# Mean: 30.0
# Maximum: 50
# Minimum: 10
# Sum: 150

# %%
import pandas as pd

data = {
    "Name": ["Arun", "Bala", "Kumar", "Ravi"],
    "Marks": [75, 82, 91, 68]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     Name  Marks
# 0   Arun     75
# 1   Bala     82
# 2  Kumar     91
# 3   Ravi     68

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 30, 25]

plt.plot(x, y, marker="o")
plt.title("Matplotlib Line Graph")
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.show()

# %%
marks = [55, 72, 89, 95, 68, 80, 77, 92]

sns.histplot(marks, kde=True)

plt.title("Seaborn Marks Distribution")
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.show()

# %%
from scipy import stats

marks = [55, 72, 89, 95, 68, 80, 77, 92]

print("Mean:", np.mean(marks))
print("Standard Deviation:", np.std(marks))
# Out:
# Mean: 78.5
# Standard Deviation: 12.619429464123963

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 5, 8, 10])

x = sm.add_constant(x)

model = sm.OLS(y, x)
result = model.fit()

print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.980
# Model:                            OLS   Adj. R-squared:                  0.974
# Method:                 Least Squares   F-statistic:                     150.0
# Date:                Thu, 30 Jul 2026   Prob (F-statistic):            0.00117
# Time:                        07:38:43   Log-Likelihood:                -2.5132
# No. Observations:                   5   AIC:                             9.026
# Df Residuals:                       3   BIC:                             8.245
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2000      0.542     -0.369      0.736      -1.924       1.524
# ...

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

output_notebook()

x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 30, 25]

p = figure(
    title="Bokeh Interactive Graph",
    x_axis_label="X",
    y_axis_label="Y"
)

p.line(x, y, line_width=2)
p.circle(x, y, size=8)

show(p)
# Out:
# ...
#   <div id="d09cbfb3-676f-4ae0-ba50-fcec13f53c22" data-root-id="p1008" style="display: contents;"></div>
