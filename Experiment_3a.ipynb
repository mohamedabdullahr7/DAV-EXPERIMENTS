# %% [markdown]
# <a href="https://colab.research.google.com/github/Iniyan-T/Data_Analytics_visualization/blob/main/Dav_3a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from scipy.stats import skew, kurtosis
# Import Datasets
uci_diabetes = pd.read_csv("/content/uci_diabetes.csv")
pima_diabetes = pd.read_csv("/content/pima_diabetes.csv")
# Display Dataset Samples
print("UCI Diabetes Dataset Sample:")
print(uci_diabetes.head())
print("\nPima Indians Diabetes Dataset Sample:")
print(pima_diabetes.head())
# Define Relevant Numerical Columns
numerical_columns = ["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI",
"DiabetesPedigreeFunction", "Age"]
# Univariate Analysis Function
def univariate_analysis(df, columns):
    stats = {}
    for col in columns:
        stats[col] = {
            "Mean": np.mean(df[col]),
            "Median": np.median(df[col]),
            "Mode": df[col].mode()[0],
            "Variance": np.var(df[col], ddof=1),
            "Standard Deviation": np.std(df[col], ddof=1),
            "Skewness": skew(df[col]),
            "Kurtosis": kurtosis(df[col])
        }
    return pd.DataFrame(stats).T
# Perform Univariate Analysis
uci_stats = univariate_analysis(uci_diabetes, numerical_columns)
pima_stats = univariate_analysis(pima_diabetes, numerical_columns)
# Display Results
print("\nUCI Diabetes Dataset Statistics:")
print(uci_stats)
print("\nPima Indians Diabetes Dataset Statistics:")
print(pima_stats)
# Out:
# UCI Diabetes Dataset Sample:
#    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0      172             84             46      150  20.3
# 1      162             65             51      159  34.1
# 2       84             90             59      231  44.6
# 3      176             85              7      146  32.5
# 4      141             82             22       84  42.9
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     1.881   27        0
# 1                     0.578   34        0
# 2                     1.986   35        1
# 3                     1.541   73        1
# 4                     0.357   27        1
#
# Pima Indians Diabetes Dataset Sample:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            3       54             45             93       68  26.9
# 1            5      143            118             46      117  10.3
# 2            2       11             15             34       58  38.4
# 3            8      144              0             18       32  18.6
# 4            4      143             62              7      317  61.7
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.345   37        0
# 1                     1.482   46        1
# 2                     2.425   41        1
# 3                     0.976   28        1
# 4                     0.202   41        0
#
# UCI Diabetes Dataset Statistics:
#                                 Mean    Median    Mode     Variance  \
# Glucose                   138.500000  139.5000  182.00  1486.723618
# BloodPressure              82.280000   82.0000   82.00   284.906131
# SkinThickness              33.800000   34.5000   18.00   225.638191
# Insulin                   158.735000  160.5000   15.00  6914.085201
# BMI                        31.741500   32.5000   20.40    57.805556
# DiabetesPedigreeFunction    1.379095    1.4005    0.29     0.458122
# Age                        51.740000   54.0000   79.00   310.585327
#
#                           Standard Deviation  Skewness  Kurtosis
# Glucose                            38.558055 -0.118226 -1.181526
# BloodPressure                      16.879163 -0.185834 -1.009817
# SkinThickness                      15.021258 -0.015626 -1.132686
# Insulin                            83.150978 -0.079223 -1.229708
# BMI                                 7.602996 -0.140404 -1.122943
# DiabetesPedigreeFunction            0.676847 -0.156186 -1.078238
# Age                                17.623431 -0.113726 -1.237959
#
# Pima Indians Diabetes Dataset Statistics:
#                                 Mean   Median     Mode      Variance  \
# Glucose                   101.691406  107.000  148.000   3292.417032
# BloodPressure              60.191406   58.500   46.000   1206.394867
# SkinThickness              49.764323   50.000   12.000    841.257291
# Insulin                   426.555990  426.500  206.000  57709.600512
# BMI                        32.544922   31.500    3.400    370.865033
# DiabetesPedigreeFunction    1.263496    1.235    1.632      0.498332
# Age                        50.294271   50.000   32.000    299.678611
#
#                           Standard Deviation  Skewness  Kurtosis
# Glucose                            57.379587 -0.127980 -1.163420
# BloodPressure                      34.733195  0.090804 -1.155597
# SkinThickness                      29.004436  0.016828 -1.218856
# Insulin                           240.228226 -0.020225 -1.168822
# BMI                                19.257856  0.062627 -1.192734
# DiabetesPedigreeFunction            0.705926  0.052576 -1.212094
# Age                                17.311228  0.052747 -1.213766
