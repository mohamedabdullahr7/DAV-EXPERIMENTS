# %% [markdown]
# <a href="https://colab.research.google.com/github/Iniyan-T/Data_Analytics_visualization/blob/main/Dav_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# Load dataset into a DataFrame
df = pd.read_csv('Data.csv')
# Display first and last few rows
print("First 5 rows:\n", df.head())
print("Last 5 rows:\n", df.tail())
# Check data types and general info
df.info()
# Summary statistics
print("Summary statistics:\n", df.describe())
# Handle missing values
df.fillna(df.mean(numeric_only=True), inplace=True)
# Create a new column
df['new_column'] = df['Age'] * 2
# Create a Series and perform operations
series = df['Age']
print("Series addition:", series + 10)
# Filter rows based on conditions
filtered_df = df[(df['Age'] > 30) & (df['Salary'] < 70000)]
print("Filtered DataFrame:\n", filtered_df)
# Grouping and aggregation
grouped = df.groupby('Country')['Age'].mean()
print("Grouped mean:\n", grouped)
# Sorting
df_sorted = df.sort_values(by='Age', ascending=False)
print("Sorted DataFrame:\n", df_sorted)
# Boolean masking
masked_df = df[df['Age'] > df['Age'].median()]
print("Masked DataFrame:\n", masked_df)
# Remove duplicates and drop missing values
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)
# Create a new DataFrame with selected columns
subset_df = df[['Country', 'Age']]
# Save the new DataFrame to a CSV file
subset_df.to_csv('filtered_data.csv', index=False)
# Compute summary statistics
print("Total sum:", df['Age'].sum())
print("Mean:", df['Age'].mean())
print("Standard Deviation:", df['Age'].std())
# Out:
# First 5 rows:
#     Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# Last 5 rows:
#     Country   Age   Salary Purchased
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    10 non-null     object
#  1   Age        9 non-null      float64
#  2   Salary     9 non-null      float64
#  3   Purchased  10 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 452.0+ bytes
# Summary statistics:
#               Age        Salary
# count   9.000000      9.000000
# ...
